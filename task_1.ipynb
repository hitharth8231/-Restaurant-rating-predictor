# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Dataset .csv')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
def fill_row_with_mode(row):
    mode = row.mode(dropna=True)
    if not mode.empty:
        return row.fillna(mode[0])
    return row

# %%
df= df.apply(fill_row_with_mode, axis=1)
# Out:
# <ipython-input-6-3ff5ebcaa45c>:2: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'float'
#   mode = row.mode(dropna=True)
# <ipython-input-6-3ff5ebcaa45c>:2: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   mode = row.mode(dropna=True)
# <ipython-input-6-3ff5ebcaa45c>:2: UserWarning: Unable to sort modes: '<' not supported between instances of 'int' and 'str'
#   mode = row.mode(dropna=True)
# <ipython-input-6-3ff5ebcaa45c>:2: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   mode = row.mode(dropna=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.size
# Out:
# 200571

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   int64
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   int64
#  4   Address               9551 non-null   int64
#  5   Locality              9551 non-null   int64
#  6   Locality Verbose      9551 non-null   int64
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   int64
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   int64
#  12  Has Table booking     9551 non-null   int64
#  13  Has Online delivery   9551 non-null   int64
#  14  Is delivering now     9551 non-null   int64
# ...

# %%
df.head(4)
# Out:
#    Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0        6317637             3748           162    73     8685       171
# 1        6304287             3172           162    73     6055       593
# 2        6300002             2896           162    75     4684       308
# 3        6318506             4707           162    75     8690       862
#
#    Locality Verbose   Longitude   Latitude  Cuisines  ...  Currency  \
# 0               172  121.027535  14.565443       920  ...         0
# 1               601  121.014101  14.553708      1111  ...         0
# 2               314  121.056831  14.581404      1672  ...         0
# 3               875  121.056475  14.585318      1126  ...         0
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# 0                  1                    0                  0
# 1                  1                    0                  0
# 2                  1                    0                  0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns=['Aggregate rating'])
y = df['Aggregate rating']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3 ,random_state=44)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
print("R2 score : " ,r2_score(y_test,y_pred))
# Out:
# R2 score :  0.9764677393596974

# %%
import matplotlib.pyplot as plt

importance_df = dt.feature_importances_
features=x_train.columns
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance':importances}).sort_values(by='Importance')

print(importance_df)
# Out:
#                  Feature  Importance
# 15  Switch to order menu    0.000000
# 18           Rating text    0.000000
# 2           Country Code    0.000008
# 11              Currency    0.000015
# 14     Is delivering now    0.000067
# 16           Price range    0.000070
# 12     Has Table booking    0.000084
# 13   Has Online delivery    0.000237
# 3                   City    0.000260
# 5               Locality    0.000677
# 6       Locality Verbose    0.000844
# 10  Average Cost for two    0.000889
# 9               Cuisines    0.000963
# 8               Latitude    0.001065
# 4                Address    0.001193
# 7              Longitude    0.001343
# 1        Restaurant Name    0.001612
# 0          Restaurant ID    0.002241
# 17          Rating color    0.089171
# 19                 Votes    0.899261

# %%
importance_df.head().plot(kind='barh',
                         x='Feature',
                         y='Importance',
                         figsize=(10,6),
                         color='blue')
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
import joblib
joblib.dump(dt,'model.pkl')
# Out:
# ['model.pkl']
